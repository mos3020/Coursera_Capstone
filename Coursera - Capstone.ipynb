# %%
#This Notebook will be used for the Final Project - Capstone Project

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("¡Hola, Proyecto Final de Curso!")
# Out:
# ¡Hola, Proyecto Final de Curso!
